# %% [markdown]
# <a href="https://colab.research.google.com/github/eviezwei/amazonsales/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from collections import Counter
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %pip install nltk
# %pip install textblob

import nltk
from nltk.corpus import stopwords
# from textblob import TextBlob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# -----------------------------
# 1. Load & Inspect the Data
# -----------------------------
path = "/content/drive/MyDrive/Colab Notebooks/01_portfolio/202510_amazon sales/amazon.csv"
df = pd.read_csv(path)

# %%
print("\nBasic Info:")
print(df.info())
print("\nMissing Values:")
print(df.isna().sum())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
display(df.head(5))
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
# -----------------------------
# 2. Data Cleaning
# -----------------------------

# Drop duplicates
df = df.drop_duplicates()

# %%
# Ensure numeric variables
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df['rating_count'] = df['rating_count'].replace('[,]', '', regex=True).fillna(0).astype(int)

# %%
# Convert price to US Dollars and convert to numeric type
df['discounted_price'] = df['discounted_price'].replace('[₹,]', '', regex=True).astype(float).astype(int)

conversion_rate = 0.012
df['discounted_price_usd'] = df['discounted_price'] * conversion_rate
df['discounted_price_usd'] = df['discounted_price_usd'].round(2)

# %%
df['actual_price'] = df['actual_price'].replace('[₹,]', '', regex=True).astype(float).astype(int)

conversion_rate = 0.012
df['actual_price_usd'] = df['actual_price'] * conversion_rate
df['actual_price_usd'] = df['actual_price_usd'].round(2)

# %%
df['discount_percentage_usd'] = 1- df['discounted_price_usd'] / df['actual_price_usd']
df['discount_percentage_usd'] = df['discount_percentage_usd'].round(2)

# %%
# Seperate IDs in review_id and count IDs
df['review_count'] = df['review_id'].apply(lambda x: len(str(x).split(',')) if pd.notna(x) else 0)

# %%
# Split "category" to several columns

split_columns = df['category'].str.split('|', expand=True)
split_columns.columns = [f'category_{i+1}' for i in range(split_columns.shape[1])]

df = df.join(split_columns)

# %%
category_1_count = df['category_1'].nunique()
print("Number of unique values in category_1:", category_1_count)

category_2_count = df['category_2'].nunique()
print("Number of unique values in category_2:", category_2_count)

category_3_count = df['category_3'].nunique()
print("Number of unique values in category_3:", category_3_count)

category_4_count = df['category_4'].nunique()
print("Number of unique values in category_4:", category_4_count)

category_5_count = df['category_5'].nunique()
print("Number of unique values in category_5:", category_5_count)
# Out:
# Number of unique values in category_1: 9
# Number of unique values in category_2: 29
# Number of unique values in category_3: 71
# Number of unique values in category_4: 136
# Number of unique values in category_5: 56

# %%
# Ratings distribution
sns.histplot(df['rating'], bins=5)
plt.title("Ratings Distribution")
plt.show()

# %%
# ---------------------------------------------
# 3. Product-Level Performance - by Category
# ---------------------------------------------
product_summary = df.groupby(['product_id', 'product_name', 'category_4']).agg({z
    'rating': 'mean',
    'rating_count': 'max',
    'discounted_price_usd': 'mean',
    'actual_price_usd': 'mean',
    'discount_percentage_usd': 'mean',
    'review_count': 'mean'
}).reset_index()

# Rename the columns
product_summary.columns = ['product_id', 'product_name', 'category',
                           'avg_rating', 'max_rating_count',
                           'avg_discounted_price', 'avg_actual_price', 'avg_discount_pct', 'avg_review_count']

# %%
# Get the top product in each category (highest avg_rating) ---
top_products = (
    product_summary
    .sort_values(['avg_rating', 'max_rating_count'], ascending=[False, False])
    .groupby('category')
    .head(1)
    .reset_index(drop=True)
)

top_products
# Out:
#      product_id                                       product_name  \
# 0    B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 1    B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 2    B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
# 3    B0B53DS4TF  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...
# 4    B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# ..          ...                                                ...
# 131  B09LRZYBH1  KRISONS Thunder Speaker, Multimedia Home Theat...
# 132  B009P2LK80  Bajaj Deluxe 2000 Watts Halogen Room Heater (S...
# 133  B009LJ2BXA  Hp Wired On Ear Headphones With Mic With 3.5 M...
# 134  B097JVLW3L  Irusu Play VR Plus Virtual Reality Headset wit...
# 135  B0B4KPCBSH                              IKEA Frother for Milk
#
#                 category  avg_rating  max_rating_count  avg_discounted_price  \
# 0                   Mice         5.0                23                  5.99
# ...

# %%
# -----------------------------------------------
# 4. Pricing & Discount Strategy (All Categories)
# -----------------------------------------------
# Average discount per category
avg_category = (
    df.groupby('category_4')
      .agg({
          'discount_percentage_usd': 'mean',
          'rating': 'mean'
      })
      .sort_values(by=['rating', 'discount_percentage_usd'], ascending=[False, False])
)

avg_category.columns = ['avg_discount_pct', 'avg_rating']

print("\nAverage Discount by Category:\n", avg_category)
# Out:
# Average Discount by Category:
#                    avg_discount_pct  avg_rating
# category_4
# PowerLANAdapters             0.400         4.5
# CoffeePresses                0.270         4.5
# Basic                        0.000         4.5
# Film                         0.000         4.5
# StreamingClients             0.000         4.5
# ...                            ...         ...
# PCMicrophones                0.565         3.6
# InkjetPrinters               0.115         3.6
# PCHeadsets                   0.350         3.5
# 3DGlasses                    0.230         3.5
# CoffeeGrinders               0.510         3.3
#
# [136 rows x 2 columns]

# %%
# Correlation between discount and rating
correlation = df[['discount_percentage_usd', 'rating']].corr()
print("\nCorrelation between Discount % and Rating:\n", correlation)
# the result shows a weak negative correlation
# Out:
# Correlation between Discount % and Rating:
#                           discount_percentage_usd    rating
# discount_percentage_usd                 1.000000 -0.155155
# rating                                 -0.155155  1.000000

# %%
# Discount vs Rating Scatter Plot
sns.scatterplot(x='discount_percentage_usd', y='rating', data=df)
plt.title("Discount % vs Rating")
plt.show()

# %%
# ----------------------------------------------
# 5. User Behavior Analysis - Most Active Users
# ----------------------------------------------
from collections import Counter

# 1. Split all user_ids and flatten into a single list
all_users = [uid.strip() for ids in df['user_id'].dropna() for uid in ids.split(',')]

# 2. Count occurrences of each user_id
user_counts = Counter(all_users)

# %%
# 3. Convert to DataFrame for better display
user_count_df = pd.DataFrame(user_counts.items(), columns=['user_id', 'count']).sort_values(by='count', ascending=False)

print(user_count_df.head(10))
# Out:
#                           user_id  count
# 161  AE55KTFVNXYFD5FPYWP2OUPEYNPQ     11
# 167  AG5DWPD54QGSLWJ6QUFERLPNAX4Q     11
# 8    AECPFYFQVRUWC3KGNLJIOREFP5LQ     10
# 166  AF355FTXYAKFH5NYPRTE7SL3WO3Q     10
# 165  AEAMIR3CMSA32IDEINSJKHRNANTA     10
# 164  AFHROSCGIXUPV3FYQ7H5QOD46Q7Q     10
# 163  AHMGAC6QM62UXNEOCZIHLHSXPP2Q     10
# 160  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA     10
# 162  AEBWA5I4QFCA3P3OBEPMELBGN4GQ     10
# 7    AFC3FFC5PKFF5PMA52S3VCHOZ5FQ      9

# %%
# ------------------------------------------------
# 6. Check High Rating Product Count by Category
# ------------------------------------------------
high_rating_df = df[df['rating'] >= 4]
product_count_per_category = high_rating_df.groupby('category_4')['product_id'].count().sort_values(ascending=False)
print(product_count_per_category)
# Out:
# category_4
# Cables                         229
# Smartphones                     59
# SmartTelevisions                59
# Irons,Steamers&Accessories      44
# Chargers                        30
#                               ...
# Split-SystemAirConditioners      1
# TableFans                        1
# TonerCartridges                  1
# WeighingScales                   1
# YogurtMakers                     1
# Name: product_id, Length: 121, dtype: int64

# %%
# -------------------------
# Pick "Cables" to dive in
# -------------------------

df_cable = df[df['category_4'] == 'Cables']

p80 = df_cable['rating'].quantile(0.80)
p20 = df_cable['rating'].quantile(0.2)
print("80th percentile rating for Cables:", p80)
print('20th percentile rating for Cables:', p20)
# Out:
# 80th percentile rating for Cables: 4.3
# 20th percentile rating for Cables: 4.0

# %%
df_cable_top = df_cable[df_cable['rating'] >= p80]
df_cable_low = df_cable[df_cable['rating'] < p20]
